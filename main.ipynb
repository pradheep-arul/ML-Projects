# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Reading the data from the CSV file - Downloaded from https://www.kaggle.com/datasets/camnugent/california-housing-prices
original_data = pd.read_csv('housing.csv')
original_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# Info Step
# Getting the information of the data
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# Remove the null values
data = original_data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# Setting the input(X) and output(y) values
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Merging the input and output values to find the Correlation between the input features and output
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12363    -116.47     33.84                 3.0       9169.0          1512.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 7237     -118.13     34.01                45.0       1179.0           268.0
# 13446    -117.43     34.07                18.0       2453.0           537.0
# 10245    -117.86     33.90                25.0       3205.0           409.0
# ...          ...       ...                 ...          ...             ...
# 1974     -120.66     38.61                19.0       2715.0           596.0
# 3346     -120.96     41.12                29.0        779.0           136.0
# 4236     -118.31     34.12                39.0       3895.0           561.0
# 3457     -118.44     34.31                14.0       4151.0           941.0
# 19857    -119.42     36.35                20.0       1469.0           303.0
#
#        population  households  median_income ocean_proximity  \
# 12363      3838.0      1270.0         4.3111          INLAND
# 2           496.0       177.0         7.2574        NEAR BAY
# 7237        736.0       252.0         2.7083       <1H OCEAN
# 13446      1503.0       500.0         2.3768          INLAND
# 10245      1291.0       408.0         7.2478       <1H OCEAN
# ...           ...         ...            ...             ...
# 1974       1301.0       473.0         2.5042          INLAND
# 3346        364.0       123.0         2.5000          INLAND
# 4236       1271.0       536.0         8.0073       <1H OCEAN
# 3457       3163.0       915.0         4.0301       <1H OCEAN
# 19857      1031.0       259.0         1.6645          INLAND
#
#        median_house_value
# 12363            142500.0
# 2                352100.0
# 7237             161800.0
# 13446             95300.0
# 10245            299200.0
# ...                   ...
# 1974             126400.0
# 3346              59200.0
# 4236             500001.0
# 3457             154300.0
# 19857             48000.0
#
# [16346 rows x 10 columns]

# %%
# Looking at the input ranges
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Creating a correlation map to see the correlation between the input features and output('median_house_value')
correlation_map = train_data.corr(numeric_only=True)
correlation_map
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924052           -0.114010     0.048121
# latitude            -0.924052  1.000000            0.016079    -0.039829
# housing_median_age  -0.114010  0.016079            1.000000    -0.360798
# total_rooms          0.048121 -0.039829           -0.360798     1.000000
# total_bedrooms       0.072742 -0.070415           -0.320995     0.930062
# population           0.101072 -0.110910           -0.295563     0.857171
# households           0.060326 -0.075680           -0.303200     0.919653
# median_income       -0.012568 -0.085202           -0.118323     0.195301
# median_house_value  -0.046517 -0.146532            0.106628     0.131040
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072742    0.101072    0.060326      -0.012568
# latitude                 -0.070415   -0.110910   -0.075680      -0.085202
# housing_median_age       -0.320995   -0.295563   -0.303200      -0.118323
# total_rooms               0.930062    0.857171    0.919653       0.195301
# total_bedrooms            1.000000    0.877632    0.980402      -0.010639
# population                0.877632    1.000000    0.906775       0.005079
# households                0.980402    0.906775    1.000000       0.010954
# median_income            -0.010639    0.005079    0.010954       1.000000
# median_house_value        0.047563   -0.024273    0.062891       0.689704
#
#                     median_house_value
# longitude                    -0.046517
# latitude                     -0.146532
# housing_median_age            0.106628
# total_rooms                   0.131040
# total_bedrooms                0.047563
# population                   -0.024273
# households                    0.062891
# median_income                 0.689704
# median_house_value            1.000000

# %%
# Heatmap of the correlation data
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_map, annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# Preprocessing the data
# Normalizing the data - Removing the skewness
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Split the 'ocean_proximity' column into multiple columns with boolean values of each category
ocean_proximity_split_columns = pd.get_dummies(train_data.ocean_proximity)

# %%
# Drop the 'ocean_proximity' column and replace it with the new split columns
train_data = train_data.join(ocean_proximity_split_columns).drop(['ocean_proximity'], axis=1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12363    -116.47     33.84                 3.0     9.123693        7.321850
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 7237     -118.13     34.01                45.0     7.073270        5.594711
# 13446    -117.43     34.07                18.0     7.805475        6.287859
# 10245    -117.86     33.90                25.0     8.072779        6.016157
# ...          ...       ...                 ...          ...             ...
# 1974     -120.66     38.61                19.0     7.906915        6.391917
# 3346     -120.96     41.12                29.0     6.659294        4.919981
# 4236     -118.31     34.12                39.0     8.267706        6.331502
# 3457     -118.44     34.31                14.0     8.331345        6.848005
# 19857    -119.42     36.35                20.0     7.293018        5.717028
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12363    8.252967    7.147559         4.3111            142500.0      False
# 2        6.208590    5.181784         7.2574            352100.0      False
# 7237     6.602588    5.533389         2.7083            161800.0       True
# 13446    7.315884    6.216606         2.3768             95300.0      False
# 10245    7.163947    6.013715         7.2478            299200.0       True
# ...           ...         ...            ...                 ...        ...
# 1974     7.171657    6.161207         2.5042            126400.0      False
# 3346     5.899897    4.820282         2.5000             59200.0      False
# 4236     7.148346    6.285998         8.0073            500001.0       True
# 3457     8.059592    6.820016         4.0301            154300.0       True
# 19857    6.939254    5.560682         1.6645             48000.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12363    True   False     False       False
# 2       False   False      True       False
# 7237    False   False     False       False
# 13446    True   False     False       False
# 10245   False   False     False       False
# ...       ...     ...       ...         ...
# 1974     True   False     False       False
# 3346     True   False     False       False
# 4236    False   False     False       False
# 3457    False   False     False       False
# 19857    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
# Plotting the Heatmap of the correlation data after splitting the 'ocean_proximity' column
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# Plotting the scatter plot of 'latitude' and 'longitude' with 'median_house_value' - to see the geographical distribution of the data
# Most of the expensive houses are located near the coast - assuming the immaginary coast
plt.figure(figsize=(15, 8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Feature Engineering
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
# Plotting the Heatmap of the correlation data after Feature Engineering
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# Model Building
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# Linear Regression Model
reg = LinearRegression()
scaler = StandardScaler()

# Splitting the data into input(X) and output(y) from the training data
X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
# Preparing the test data
test_data = X_test.join(y_test)

# Normalizing the test data
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# Split the 'ocean_proximity' column into multiple columns with boolean values of each category
ocean_proximity_split_columns = pd.get_dummies(test_data.ocean_proximity)
# Drop the 'ocean_proximity' column and replace it with the new split columns
test_data = test_data.join(ocean_proximity_split_columns).drop(['ocean_proximity'], axis=1)


# Feature Engineering
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
# Scale the X_test data
X_test_s = scaler.transform(X_test)

# %%
# Score the model
reg.score(X_test_s, y_test)
# Out:
# 0.6562628922008293

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8138554615413395

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [3, 10, 30],
    'max_features': [2, 4, 6, 8],
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                            scoring='neg_mean_squared_error',
                            return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_
best_forest
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8079481646741693

# %% [markdown]
# Above result was worse than the original score
# Because the default n_estimators is 100 where we used a max of 30 for tuning.
# So we should go more in that direction.

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [100, 200, 300],
    'min_samples_split': [2, 4],
    'max_depth': [None, 4, 8]

}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                            scoring='neg_mean_squared_error',
                            return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_
best_forest
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8133324398129732
